# %% [markdown]
# # OpenAQ
# [Explore data](https://explore.openaq.org/#1.2/20/40)
#
# [API docs](https://docs.openaq.org/examples/examples)
#
# This notebook is to get air quality data from OpenAQ

# %%
from openaq import OpenAQ
import requests
import json
import pandas as pd

# %%
openaq_apikey = 'b9f803d97d9a502959910d8b74cc9d94725b8a85ea028ea5e26b3f8905df0758'

headers = {
    "X-API-Key": openaq_apikey
}

# %% [markdown]
# # Daily Averages Data

# %% [markdown]
# To get the daily averages data, we need ID of the sensor whose daily average data we need. Every location (station) will have 1+ sensors. We use the locations API to get the list of sensors. I'm interested in the [New Delhi Location (8118)](https://explore.openaq.org/locations/8118)

# %%
LOCATION_ID = 8118

BASE_URL = f"https://api.openaq.org/v3/locations/{LOCATION_ID}"
response = requests.get(BASE_URL, headers=headers, params=params)
response.raise_for_status()

data = response.json()
data
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 1},
#  'results': [{'id': 8118,
#    'name': 'New Delhi',
#    'locality': 'India',
#    'timezone': 'Asia/Kolkata',
#    'country': {'id': 9, 'code': 'IN', 'name': 'India'},
#    'owner': {'id': 4, 'name': 'Unknown Governmental Organization'},
#    'provider': {'id': 119, 'name': 'AirNow'},
#    'isMobile': False,
#    'isMonitor': True,
#    'instruments': [{'id': 2, 'name': 'Government Monitor'}],
#    'sensors': [{'id': 23534,
#      'name': 'pm25 µg/m³',
#      'parameter': {'id': 2,
#       'name': 'pm25',
#       'units': 'µg/m³',
#       'displayName': 'PM2.5'}}],
#    'coordinates': {'latitude': 28.63576, 'longitude': 77.22445},
#    'licenses': [{'id': 33,
#      'name': 'US Public Domain',
#      'attribution': {'name': 'Unknown Governmental Organization', 'url': None},
#      'dateFrom': '2016-01-30',
#      'dateTo': None}],
#    'bounds': [77.22445, 28.63576, 77.22445, 28.63576],
#    'distance': None,
#    'datetimeFirst': {'utc': '2016-11-09T19:00:00Z',
#     'local': '2016-11-10T00:30:00+05:30'},
#    'datetimeLast': {'utc': '2026-01-19T09:30:00Z',
#     'local': '2026-01-19T15:00:00+05:30'}}]}

# %% [markdown]
# We can see that this location only has one PM2.5 sensor of ID 23534. We will use this ID to get its data.

# %%
SENSOR_ID = 23534
LIMIT = 1000

BASE_URL = f"https://api.openaq.org/v3/sensors/{SENSOR_ID}/days"

# %% [markdown]
# OpenAQ has a response limit of 1000. So on every API request, we'd only get 1000 rows. But OpenAQ uses pagination. So each `page` has 1000 rows. We can increase `page` to get more data. We'll append each pages data to a `master_df`

# %%
master_df = pd.DataFrame(columns=['date','pollutant','avg_value'])
master_df
# Out:
# Empty DataFrame
# Columns: [date, pollutant, avg_value]
# Index: []

# %%
params = {
        "limit": LIMIT,
        "page": 4
    }

response = requests.get(BASE_URL, headers=headers, params=params)
response.raise_for_status()

data = response.json()

# %%
for i in range(len(data['results'])):
    pollutant = data['results'][i]['parameter']['name']
    value = data['results'][i]['value']
    date = data['results'][i]['period']['datetimeFrom']['local'].split('T')[0]

    new_row = {"date": date, "pollutant": pollutant, "avg_value": value}
    master_df = master_df._append(new_row, ignore_index=True)

# %%
master_df[['date','avg_value']].to_csv('dailyaverages_pm25_8118_23534.csv',index=False)

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# There is more information beyond daily average in the response

# %%
data
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 4,
#   'limit': 1000,
#   'found': 250},
#  'results': [{'value': 27.5,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-12T18:30:00Z',
#      'local': '2025-05-13T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-13T18:30:00Z',
#      'local': '2025-05-14T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 13.0,
#     'q02': 13.46,
#     'q25': 21.75,
#     'median': 28.0,
#     'q75': 34.0,
#     'q98': 41.779999999999994,
#     'max': 45.0,
#     'avg': 27.458333333333332,
#     'sd': 8.118573266532609},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-12T19:30:00Z',
#      'local': '2025-05-13T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-13T18:30:00Z',
#      'local': '2025-05-14T00:00:00+05:30'}}},
#   {'value': 66.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-13T18:30:00Z',
#      'local': '2025-05-14T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-14T18:30:00Z',
#      'local': '2025-05-15T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 19.0,
#     'q02': 21.3,
#     'q25': 28.5,
#     'median': 40.5,
#     'q75': 50.75,
#     'q98': 359.27999999999986,
#     'max': 420.0,
#     'avg': 66.04166666666667,
#     'sd': 91.8053134612052},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-13T19:30:00Z',
#      'local': '2025-05-14T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-14T18:30:00Z',
#      'local': '2025-05-15T00:00:00+05:30'}}},
#   {'value': 211.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-14T18:30:00Z',
#      'local': '2025-05-15T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-15T18:30:00Z',
#      'local': '2025-05-16T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 35.0,
#     'q02': 40.52,
#     'q25': 64.25,
#     'median': 79.0,
#     'q75': 403.25,
#     'q98': 480.7,
#     'max': 483.0,
#     'avg': 210.95833333333334,
#     'sd': 183.05795688718408},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-14T19:30:00Z',
#      'local': '2025-05-15T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-15T18:30:00Z',
#      'local': '2025-05-16T00:00:00+05:30'}}},
#   {'value': 80.9,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-15T18:30:00Z',
#      'local': '2025-05-16T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-16T18:30:00Z',
#      'local': '2025-05-17T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 21.0,
#     'q02': 27.44,
#     'q25': 40.0,
#     'median': 70.0,
#     'q75': 133.0,
#     'q98': 156.16,
#     'max': 158.0,
#     'avg': 80.875,
#     'sd': 46.62832923187922},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-15T19:30:00Z',
#      'local': '2025-05-16T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-16T18:30:00Z',
#      'local': '2025-05-17T00:00:00+05:30'}}},
#   {'value': 36.3,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-16T18:30:00Z',
#      'local': '2025-05-17T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-17T18:30:00Z',
#      'local': '2025-05-18T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 26.0,
#     'q02': 26.92,
#     'q25': 29.75,
#     'median': 33.5,
#     'q75': 41.0,
#     'q98': 51.62,
#     'max': 53.0,
#     'avg': 36.25,
#     'sd': 7.946834206968426},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-16T19:30:00Z',
#      'local': '2025-05-17T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-17T18:30:00Z',
#      'local': '2025-05-18T00:00:00+05:30'}}},
#   {'value': 57.2,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-17T18:30:00Z',
#      'local': '2025-05-18T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-18T18:30:00Z',
#      'local': '2025-05-19T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 22.0,
#     'q02': 23.84,
#     'q25': 42.25,
#     'median': 62.0,
#     'q75': 73.25,
#     'q98': 91.17999999999998,
#     'max': 99.0,
#     'avg': 57.166666666666664,
#     'sd': 19.983194520424075},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-17T19:30:00Z',
#      'local': '2025-05-18T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-18T18:30:00Z',
#      'local': '2025-05-19T00:00:00+05:30'}}},
#   {'value': 74.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-18T18:30:00Z',
#      'local': '2025-05-19T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-19T18:30:00Z',
#      'local': '2025-05-20T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 68.0,
#     'q02': 68.46,
#     'q25': 70.75,
#     'median': 73.5,
#     'q75': 76.25,
#     'q98': 84.24,
#     'max': 87.0,
#     'avg': 73.95833333333333,
#     'sd': 4.601315186908561},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-18T19:30:00Z',
#      'local': '2025-05-19T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-19T18:30:00Z',
#      'local': '2025-05-20T00:00:00+05:30'}}},
#   {'value': 70.8,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-19T18:30:00Z',
#      'local': '2025-05-20T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-20T18:30:00Z',
#      'local': '2025-05-21T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 51.0,
#     'q02': 51.0,
#     'q25': 63.5,
#     'median': 69.0,
#     'q75': 80.25,
#     'q98': 89.16,
#     'max': 91.0,
#     'avg': 70.83333333333333,
#     'sd': 10.915956337710334},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-19T19:30:00Z',
#      'local': '2025-05-20T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-20T18:30:00Z',
#      'local': '2025-05-21T00:00:00+05:30'}}},
#   {'value': 59.5,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-20T18:30:00Z',
#      'local': '2025-05-21T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-21T18:30:00Z',
#      'local': '2025-05-22T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 15.0,
#     'q02': 15.46,
#     'q25': 62.75,
#     'median': 65.0,
#     'q75': 67.0,
#     'q98': 80.47999999999999,
#     'max': 86.0,
#     'avg': 59.5,
#     'sd': 18.050653366471856},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-20T19:30:00Z',
#      'local': '2025-05-21T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-21T18:30:00Z',
#      'local': '2025-05-22T00:00:00+05:30'}}},
#   {'value': 25.5,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-21T18:30:00Z',
#      'local': '2025-05-22T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-22T18:30:00Z',
#      'local': '2025-05-23T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 15.0,
#     'q02': 15.92,
#     'q25': 19.75,
#     'median': 25.0,
#     'q75': 29.25,
#     'q98': 39.62,
#     'max': 41.0,
#     'avg': 25.541666666666668,
#     'sd': 7.318702466769738},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-21T19:30:00Z',
#      'local': '2025-05-22T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-22T18:30:00Z',
#      'local': '2025-05-23T00:00:00+05:30'}}},
#   {'value': 41.4,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-22T18:30:00Z',
#      'local': '2025-05-23T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-23T18:30:00Z',
#      'local': '2025-05-24T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 28.0,
#     'q02': 28.46,
#     'q25': 34.75,
#     'median': 41.5,
#     'q75': 47.25,
#     'q98': 58.239999999999995,
#     'max': 61.0,
#     'avg': 41.416666666666664,
#     'sd': 8.722368379340988},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-22T19:30:00Z',
#      'local': '2025-05-23T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-23T18:30:00Z',
#      'local': '2025-05-24T00:00:00+05:30'}}},
#   {'value': 53.1,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-23T18:30:00Z',
#      'local': '2025-05-24T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-24T18:30:00Z',
#      'local': '2025-05-25T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 44.0,
#     'q02': 44.46,
#     'q25': 48.0,
#     'median': 53.0,
#     'q75': 56.25,
#     'q98': 63.54,
#     'max': 64.0,
#     'avg': 53.083333333333336,
#     'sd': 5.800424772051775},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-23T19:30:00Z',
#      'local': '2025-05-24T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-24T18:30:00Z',
#      'local': '2025-05-25T00:00:00+05:30'}}},
#   {'value': 24.1,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-24T18:30:00Z',
#      'local': '2025-05-25T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-25T18:30:00Z',
#      'local': '2025-05-26T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 0.0,
#     'q02': 0.92,
#     'q25': 15.75,
#     'median': 22.0,
#     'q75': 29.25,
#     'q98': 54.0,
#     'max': 54.0,
#     'avg': 24.125,
#     'sd': 16.103773524833564},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-24T19:30:00Z',
#      'local': '2025-05-25T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-25T18:30:00Z',
#      'local': '2025-05-26T00:00:00+05:30'}}},
#   {'value': 46.7,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-25T18:30:00Z',
#      'local': '2025-05-26T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-26T18:30:00Z',
#      'local': '2025-05-27T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 25.0,
#     'q02': 25.46,
#     'q25': 31.0,
#     'median': 45.0,
#     'q75': 50.25,
#     'q98': 105.89999999999998,
#     'max': 122.0,
#     'avg': 46.708333333333336,
#     'sd': 21.798442638162832},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-25T19:30:00Z',
#      'local': '2025-05-26T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-26T18:30:00Z',
#      'local': '2025-05-27T00:00:00+05:30'}}},
#   {'value': 44.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-26T18:30:00Z',
#      'local': '2025-05-27T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-27T18:30:00Z',
#      'local': '2025-05-28T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 29.0,
#     'q02': 29.92,
#     'q25': 37.0,
#     'median': 43.5,
#     'q75': 48.25,
#     'q98': 58.54,
#     'max': 59.0,
#     'avg': 43.958333333333336,
#     'sd': 8.71519994864877},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-26T19:30:00Z',
#      'local': '2025-05-27T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-27T18:30:00Z',
#      'local': '2025-05-28T00:00:00+05:30'}}},
#   {'value': 53.1,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-27T18:30:00Z',
#      'local': '2025-05-28T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-28T18:30:00Z',
#      'local': '2025-05-29T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 26.0,
#     'q02': 26.92,
#     'q25': 42.0,
#     'median': 55.5,
#     'q75': 62.75,
#     'q98': 78.16,
#     'max': 80.0,
#     'avg': 53.083333333333336,
#     'sd': 15.004105718295815},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-27T19:30:00Z',
#      'local': '2025-05-28T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-28T18:30:00Z',
#      'local': '2025-05-29T00:00:00+05:30'}}},
#   {'value': 51.1,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-28T18:30:00Z',
#      'local': '2025-05-29T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-29T18:30:00Z',
#      'local': '2025-05-30T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 35.0,
#     'q02': 36.38,
#     'q25': 45.25,
#     'median': 51.0,
#     'q75': 55.75,
#     'q98': 68.62,
#     'max': 70.0,
#     'avg': 51.083333333333336,
#     'sd': 9.038346065776805},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-28T19:30:00Z',
#      'local': '2025-05-29T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-29T18:30:00Z',
#      'local': '2025-05-30T00:00:00+05:30'}}},
#   {'value': 58.5,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-29T18:30:00Z',
#      'local': '2025-05-30T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-30T18:30:00Z',
#      'local': '2025-05-31T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 39.0,
#     'q02': 39.92,
#     'q25': 48.0,
#     'median': 58.5,
#     'q75': 67.25,
#     'q98': 79.39999999999999,
#     'max': 84.0,
#     'avg': 58.458333333333336,
#     'sd': 12.186875216241113},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-29T19:30:00Z',
#      'local': '2025-05-30T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-30T18:30:00Z',
#      'local': '2025-05-31T00:00:00+05:30'}}},
#   {'value': 63.4,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-30T18:30:00Z',
#      'local': '2025-05-31T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-31T18:30:00Z',
#      'local': '2025-06-01T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 38.0,
#     'q02': 39.38,
#     'q25': 55.5,
#     'median': 62.5,
#     'q75': 69.75,
#     'q98': 101.53999999999999,
#     'max': 102.0,
#     'avg': 63.416666666666664,
#     'sd': 15.800155933921408},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-30T19:30:00Z',
#      'local': '2025-05-31T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-05-31T18:30:00Z',
#      'local': '2025-06-01T00:00:00+05:30'}}},
#   {'value': 46.1,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-05-31T18:30:00Z',
#      'local': '2025-06-01T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-01T18:30:00Z',
#      'local': '2025-06-02T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 22.0,
#     'q02': 23.84,
#     'q25': 36.75,
#     'median': 47.5,
#     'q75': 54.0,
#     'q98': 67.16,
#     'max': 69.0,
#     'avg': 46.083333333333336,
#     'sd': 12.07914720091817},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-05-31T19:30:00Z',
#      'local': '2025-06-01T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-01T18:30:00Z',
#      'local': '2025-06-02T00:00:00+05:30'}}},
#   {'value': 40.6,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-01T18:30:00Z',
#      'local': '2025-06-02T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-02T18:30:00Z',
#      'local': '2025-06-03T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 16.0,
#     'q02': 20.14,
#     'q25': 30.75,
#     'median': 39.0,
#     'q75': 52.0,
#     'q98': 60.779999999999994,
#     'max': 64.0,
#     'avg': 40.625,
#     'sd': 12.412519976778004},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-01T19:30:00Z',
#      'local': '2025-06-02T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-02T18:30:00Z',
#      'local': '2025-06-03T00:00:00+05:30'}}},
#   {'value': 38.2,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-02T18:30:00Z',
#      'local': '2025-06-03T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-03T18:30:00Z',
#      'local': '2025-06-04T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 22.0,
#     'q02': 22.0,
#     'q25': 31.75,
#     'median': 38.5,
#     'q75': 43.0,
#     'q98': 53.54,
#     'max': 54.0,
#     'avg': 38.208333333333336,
#     'sd': 8.987813811013737},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-02T19:30:00Z',
#      'local': '2025-06-03T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-03T18:30:00Z',
#      'local': '2025-06-04T00:00:00+05:30'}}},
#   {'value': 48.5,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-03T18:30:00Z',
#      'local': '2025-06-04T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-04T18:30:00Z',
#      'local': '2025-06-05T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 21.0,
#     'q02': 21.46,
#     'q25': 38.75,
#     'median': 48.5,
#     'q75': 58.25,
#     'q98': 71.53999999999999,
#     'max': 72.0,
#     'avg': 48.458333333333336,
#     'sd': 14.301046379067229},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-03T19:30:00Z',
#      'local': '2025-06-04T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-04T18:30:00Z',
#      'local': '2025-06-05T00:00:00+05:30'}}},
#   {'value': 42.1,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-04T18:30:00Z',
#      'local': '2025-06-05T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-05T18:30:00Z',
#      'local': '2025-06-06T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 23.0,
#     'q02': 23.46,
#     'q25': 33.5,
#     'median': 40.0,
#     'q75': 49.25,
#     'q98': 68.39999999999999,
#     'max': 73.0,
#     'avg': 42.125,
#     'sd': 12.293665000080292},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-04T19:30:00Z',
#      'local': '2025-06-05T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-05T18:30:00Z',
#      'local': '2025-06-06T00:00:00+05:30'}}},
#   {'value': 41.2,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-05T18:30:00Z',
#      'local': '2025-06-06T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-06T18:30:00Z',
#      'local': '2025-06-07T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 29.0,
#     'q02': 29.92,
#     'q25': 34.0,
#     'median': 37.0,
#     'q75': 45.5,
#     'q98': 61.779999999999994,
#     'max': 65.0,
#     'avg': 41.208333333333336,
#     'sd': 10.316635644166793},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-05T19:30:00Z',
#      'local': '2025-06-06T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-06T18:30:00Z',
#      'local': '2025-06-07T00:00:00+05:30'}}},
#   {'value': 60.2,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-06T18:30:00Z',
#      'local': '2025-06-07T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-07T18:30:00Z',
#      'local': '2025-06-08T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 39.0,
#     'q02': 39.46,
#     'q25': 52.5,
#     'median': 59.5,
#     'q75': 71.25,
#     'q98': 81.53999999999999,
#     'max': 82.0,
#     'avg': 60.208333333333336,
#     'sd': 12.971470925497018},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-06T19:30:00Z',
#      'local': '2025-06-07T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-07T18:30:00Z',
#      'local': '2025-06-08T00:00:00+05:30'}}},
#   {'value': 60.2,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-07T18:30:00Z',
#      'local': '2025-06-08T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-08T18:30:00Z',
#      'local': '2025-06-09T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 44.0,
#     'q02': 45.38,
#     'q25': 52.5,
#     'median': 59.5,
#     'q75': 67.25,
#     'q98': 75.0,
#     'max': 75.0,
#     'avg': 60.166666666666664,
#     'sd': 9.680400039643828},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-07T19:30:00Z',
#      'local': '2025-06-08T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-08T18:30:00Z',
#      'local': '2025-06-09T00:00:00+05:30'}}},
#   {'value': 64.5,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-08T18:30:00Z',
#      'local': '2025-06-09T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-09T18:30:00Z',
#      'local': '2025-06-10T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 38.0,
#     'q02': 39.38,
#     'q25': 48.0,
#     'median': 65.5,
#     'q75': 84.75,
#     'q98': 93.78,
#     'max': 97.0,
#     'avg': 64.45833333333333,
#     'sd': 18.955277266024996},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-08T19:30:00Z',
#      'local': '2025-06-09T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-09T18:30:00Z',
#      'local': '2025-06-10T00:00:00+05:30'}}},
#   {'value': 55.1,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-09T18:30:00Z',
#      'local': '2025-06-10T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-10T18:30:00Z',
#      'local': '2025-06-11T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 30.0,
#     'q02': 31.38,
#     'q25': 43.5,
#     'median': 49.5,
#     'q75': 68.25,
#     'q98': 85.24,
#     'max': 88.0,
#     'avg': 55.125,
#     'sd': 17.207967062810834},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-09T19:30:00Z',
#      'local': '2025-06-10T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-10T18:30:00Z',
#      'local': '2025-06-11T00:00:00+05:30'}}},
#   {'value': 70.4,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-10T18:30:00Z',
#      'local': '2025-06-11T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-11T18:30:00Z',
#      'local': '2025-06-12T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 37.0,
#     'q02': 41.6,
#     'q25': 53.5,
#     'median': 70.5,
#     'q75': 85.75,
#     'q98': 101.53999999999999,
#     'max': 102.0,
#     'avg': 70.41666666666667,
#     'sd': 18.731319196484257},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-10T19:30:00Z',
#      'local': '2025-06-11T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-11T18:30:00Z',
#      'local': '2025-06-12T00:00:00+05:30'}}},
#   {'value': 69.1,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-11T18:30:00Z',
#      'local': '2025-06-12T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-12T18:30:00Z',
#      'local': '2025-06-13T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 55.0,
#     'q02': 55.0,
#     'q25': 60.5,
#     'median': 70.0,
#     'q75': 75.0,
#     'q98': 86.0,
#     'max': 86.0,
#     'avg': 69.08333333333333,
#     'sd': 9.352593998070997},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-11T19:30:00Z',
#      'local': '2025-06-12T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-12T18:30:00Z',
#      'local': '2025-06-13T00:00:00+05:30'}}},
#   {'value': 54.5,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-12T18:30:00Z',
#      'local': '2025-06-13T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-13T18:30:00Z',
#      'local': '2025-06-14T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 34.0,
#     'q02': 34.92,
#     'q25': 41.75,
#     'median': 55.5,
#     'q75': 66.25,
#     'q98': 80.78,
#     'max': 84.0,
#     'avg': 54.5,
#     'sd': 14.322375319150407},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-12T19:30:00Z',
#      'local': '2025-06-13T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-13T18:30:00Z',
#      'local': '2025-06-14T00:00:00+05:30'}}},
#   {'value': 59.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-13T18:30:00Z',
#      'local': '2025-06-14T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-14T18:30:00Z',
#      'local': '2025-06-15T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 47.0,
#     'q02': 47.46,
#     'q25': 54.75,
#     'median': 60.5,
#     'q75': 63.0,
#     'q98': 67.53999999999999,
#     'max': 68.0,
#     'avg': 59.041666666666664,
#     'sd': 5.841970830841746},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-13T19:30:00Z',
#      'local': '2025-06-14T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-14T18:30:00Z',
#      'local': '2025-06-15T00:00:00+05:30'}}},
#   {'value': 38.3,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-14T18:30:00Z',
#      'local': '2025-06-15T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-15T18:30:00Z',
#      'local': '2025-06-16T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 15.0,
#     'q02': 15.0,
#     'q25': 27.0,
#     'median': 34.5,
#     'q75': 50.75,
#     'q98': 68.24,
#     'max': 71.0,
#     'avg': 38.291666666666664,
#     'sd': 15.655195461173145},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-14T19:30:00Z',
#      'local': '2025-06-15T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-15T18:30:00Z',
#      'local': '2025-06-16T00:00:00+05:30'}}},
#   {'value': 41.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-15T18:30:00Z',
#      'local': '2025-06-16T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-16T18:30:00Z',
#      'local': '2025-06-17T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 28.0,
#     'q02': 29.84,
#     'q25': 35.0,
#     'median': 41.0,
#     'q75': 48.5,
#     'q98': 52.0,
#     'max': 52.0,
#     'avg': 41.041666666666664,
#     'sd': 7.285955320171558},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-15T19:30:00Z',
#      'local': '2025-06-16T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-16T18:30:00Z',
#      'local': '2025-06-17T00:00:00+05:30'}}},
#   {'value': 32.7,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-16T18:30:00Z',
#      'local': '2025-06-17T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-17T18:30:00Z',
#      'local': '2025-06-18T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 6.0,
#     'q02': 6.46,
#     'q25': 15.75,
#     'median': 29.0,
#     'q75': 42.5,
#     'q98': 75.62,
#     'max': 77.0,
#     'avg': 32.708333333333336,
#     'sd': 20.62391850480295},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-16T19:30:00Z',
#      'local': '2025-06-17T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-17T18:30:00Z',
#      'local': '2025-06-18T00:00:00+05:30'}}},
#   {'value': 39.9,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-17T18:30:00Z',
#      'local': '2025-06-18T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-18T18:30:00Z',
#      'local': '2025-06-19T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 18.0,
#     'q02': 18.0,
#     'q25': 28.75,
#     'median': 38.5,
#     'q75': 50.5,
#     'q98': 64.69999999999999,
#     'max': 67.0,
#     'avg': 39.875,
#     'sd': 14.635610235194218},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-17T19:30:00Z',
#      'local': '2025-06-18T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-18T18:30:00Z',
#      'local': '2025-06-19T00:00:00+05:30'}}},
#   {'value': 32.2,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-18T18:30:00Z',
#      'local': '2025-06-19T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-19T18:30:00Z',
#      'local': '2025-06-20T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 13.0,
#     'q02': 14.38,
#     'q25': 23.0,
#     'median': 30.5,
#     'q75': 38.75,
#     'q98': 54.08,
#     'max': 55.0,
#     'avg': 32.208333333333336,
#     'sd': 12.576563937511244},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-18T19:30:00Z',
#      'local': '2025-06-19T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-19T18:30:00Z',
#      'local': '2025-06-20T00:00:00+05:30'}}},
#   {'value': 26.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-19T18:30:00Z',
#      'local': '2025-06-20T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-20T18:30:00Z',
#      'local': '2025-06-21T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 15.0,
#     'q02': 15.46,
#     'q25': 20.75,
#     'median': 22.5,
#     'q75': 28.0,
#     'q98': 47.54,
#     'max': 48.0,
#     'avg': 26.041666666666668,
#     'sd': 9.22887324917161},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-19T19:30:00Z',
#      'local': '2025-06-20T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-20T18:30:00Z',
#      'local': '2025-06-21T00:00:00+05:30'}}},
#   {'value': 29.3,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-20T18:30:00Z',
#      'local': '2025-06-21T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-21T18:30:00Z',
#      'local': '2025-06-22T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 12.0,
#     'q02': 12.92,
#     'q25': 23.0,
#     'median': 26.5,
#     'q75': 36.25,
#     'q98': 45.62,
#     'max': 47.0,
#     'avg': 29.291666666666668,
#     'sd': 9.387684655355962},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-20T19:30:00Z',
#      'local': '2025-06-21T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-21T18:30:00Z',
#      'local': '2025-06-22T00:00:00+05:30'}}},
#   {'value': 33.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-21T18:30:00Z',
#      'local': '2025-06-22T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-22T18:30:00Z',
#      'local': '2025-06-23T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 12.0,
#     'q02': 13.84,
#     'q25': 26.75,
#     'median': 35.0,
#     'q75': 39.5,
#     'q98': 50.239999999999995,
#     'max': 53.0,
#     'avg': 33.0,
#     'sd': 10.121592775655694},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-21T19:30:00Z',
#      'local': '2025-06-22T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-22T18:30:00Z',
#      'local': '2025-06-23T00:00:00+05:30'}}},
#   {'value': 39.6,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-22T18:30:00Z',
#      'local': '2025-06-23T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-23T18:30:00Z',
#      'local': '2025-06-24T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 15.0,
#     'q02': 17.76,
#     'q25': 27.0,
#     'median': 43.0,
#     'q75': 50.25,
#     'q98': 58.08,
#     'max': 59.0,
#     'avg': 39.625,
#     'sd': 13.041890548954514},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-22T19:30:00Z',
#      'local': '2025-06-23T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-23T18:30:00Z',
#      'local': '2025-06-24T00:00:00+05:30'}}},
#   {'value': 42.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-23T18:30:00Z',
#      'local': '2025-06-24T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-24T18:30:00Z',
#      'local': '2025-06-25T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 25.0,
#     'q02': 27.3,
#     'q25': 34.75,
#     'median': 37.0,
#     'q75': 46.25,
#     'q98': 74.01999999999998,
#     'max': 80.0,
#     'avg': 41.958333333333336,
#     'sd': 12.790890667110364},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-23T19:30:00Z',
#      'local': '2025-06-24T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-24T18:30:00Z',
#      'local': '2025-06-25T00:00:00+05:30'}}},
#   {'value': 54.3,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-24T18:30:00Z',
#      'local': '2025-06-25T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-25T18:30:00Z',
#      'local': '2025-06-26T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 37.0,
#     'q02': 38.84,
#     'q25': 47.0,
#     'median': 50.0,
#     'q75': 57.5,
#     'q98': 83.16,
#     'max': 85.0,
#     'avg': 54.291666666666664,
#     'sd': 12.273970927081447},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-24T19:30:00Z',
#      'local': '2025-06-25T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-25T18:30:00Z',
#      'local': '2025-06-26T00:00:00+05:30'}}},
#   {'value': 29.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-25T18:30:00Z',
#      'local': '2025-06-26T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-26T18:30:00Z',
#      'local': '2025-06-27T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 13.0,
#     'q02': 14.84,
#     'q25': 21.0,
#     'median': 26.5,
#     'q75': 33.25,
#     'q98': 54.39999999999999,
#     'max': 59.0,
#     'avg': 29.041666666666668,
#     'sd': 12.05515822487784},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-25T19:30:00Z',
#      'local': '2025-06-26T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-26T18:30:00Z',
#      'local': '2025-06-27T00:00:00+05:30'}}},
#   {'value': 21.1,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-26T18:30:00Z',
#      'local': '2025-06-27T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-27T18:30:00Z',
#      'local': '2025-06-28T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 13.0,
#     'q02': 13.46,
#     'q25': 19.75,
#     'median': 21.0,
#     'q75': 22.5,
#     'q98': 30.08,
#     'max': 31.0,
#     'avg': 21.125,
#     'sd': 4.316527663202644},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-26T19:30:00Z',
#      'local': '2025-06-27T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-27T18:30:00Z',
#      'local': '2025-06-28T00:00:00+05:30'}}},
#   {'value': 25.8,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-27T18:30:00Z',
#      'local': '2025-06-28T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-28T18:30:00Z',
#      'local': '2025-06-29T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 8.0,
#     'q02': 8.92,
#     'q25': 14.75,
#     'median': 19.5,
#     'q75': 39.25,
#     'q98': 53.08,
#     'max': 54.0,
#     'avg': 25.75,
#     'sd': 14.659171339056858},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2025-06-27T19:30:00Z',
#      'local': '2025-06-28T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-28T18:30:00Z',
#      'local': '2025-06-29T00:00:00+05:30'}}},
#   {'value': 35.5,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2025-06-28T18:30:00Z',
#      'local': '2025-06-29T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2025-06-29T18:30:00Z',
#      'local': '2025-06-30T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 10.0,
#     'q02': 11.38,
#     'q25': 24.5,
#     'median': 35.0,
#     'q75': 46.0,
#     'q98': 64.24,
#     'max': 67.0,
# ...
#      'local': '2026-01-03T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-03T18:30:00Z',
#      'local': '2026-01-04T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 99.0,
#     'q02': 100.38,
#     'q25': 123.25,
#     'median': 145.5,
#     'q75': 165.5,
#     'q98': 208.32,
#     'max': 212.0,
#     'avg': 146.25,
#     'sd': 30.85062186675039},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-02T19:30:00Z',
#      'local': '2026-01-03T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-03T18:30:00Z',
#      'local': '2026-01-04T00:00:00+05:30'}}},
#   {'value': 139.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-03T18:30:00Z',
#      'local': '2026-01-04T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-04T18:30:00Z',
#      'local': '2026-01-05T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 93.0,
#     'q02': 100.82,
#     'q25': 121.0,
#     'median': 147.0,
#     'q75': 156.25,
#     'q98': 166.54,
#     'max': 167.0,
#     'avg': 138.83333333333334,
#     'sd': 20.8444897664392},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-03T19:30:00Z',
#      'local': '2026-01-04T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-04T18:30:00Z',
#      'local': '2026-01-05T00:00:00+05:30'}}},
#   {'value': 132.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-04T18:30:00Z',
#      'local': '2026-01-05T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-05T18:30:00Z',
#      'local': '2026-01-06T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 84.0,
#     'q02': 86.3,
#     'q25': 99.5,
#     'median': 120.5,
#     'q75': 143.0,
#     'q98': 215.48,
#     'max': 221.0,
#     'avg': 131.95833333333334,
#     'sd': 39.33852980903368},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-04T19:30:00Z',
#      'local': '2026-01-05T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-05T18:30:00Z',
#      'local': '2026-01-06T00:00:00+05:30'}}},
#   {'value': 186.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-05T18:30:00Z',
#      'local': '2026-01-06T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-06T18:30:00Z',
#      'local': '2026-01-07T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 153.0,
#     'q02': 155.3,
#     'q25': 174.75,
#     'median': 180.5,
#     'q75': 195.25,
#     'q98': 227.64,
#     'max': 235.0,
#     'avg': 185.70833333333334,
#     'sd': 19.400760107625246},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-05T19:30:00Z',
#      'local': '2026-01-06T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-06T18:30:00Z',
#      'local': '2026-01-07T00:00:00+05:30'}}},
#   {'value': 155.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-06T18:30:00Z',
#      'local': '2026-01-07T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-07T18:30:00Z',
#      'local': '2026-01-08T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 117.0,
#     'q02': 118.84,
#     'q25': 129.0,
#     'median': 154.5,
#     'q75': 161.25,
#     'q98': 228.79999999999998,
#     'max': 238.0,
#     'avg': 155.04166666666666,
#     'sd': 32.19165320749906},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-06T19:30:00Z',
#      'local': '2026-01-07T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-07T18:30:00Z',
#      'local': '2026-01-08T00:00:00+05:30'}}},
#   {'value': 168.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-07T18:30:00Z',
#      'local': '2026-01-08T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-08T18:30:00Z',
#      'local': '2026-01-09T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 105.0,
#     'q02': 105.46,
#     'q25': 118.0,
#     'median': 166.0,
#     'q75': 200.25,
#     'q98': 274.64,
#     'max': 282.0,
#     'avg': 168.41666666666666,
#     'sd': 52.81132673853269},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-07T19:30:00Z',
#      'local': '2026-01-08T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-08T18:30:00Z',
#      'local': '2026-01-09T00:00:00+05:30'}}},
#   {'value': 215.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-08T18:30:00Z',
#      'local': '2026-01-09T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-09T18:30:00Z',
#      'local': '2026-01-10T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 143.0,
#     'q02': 149.16,
#     'q25': 181.0,
#     'median': 201.0,
#     'q75': 251.0,
#     'q98': 286.8,
#     'max': 289.0,
#     'avg': 215.04347826086956,
#     'sd': 44.05005237936167},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 23,
#     'observedInterval': '23:00:00',
#     'percentComplete': 96.0,
#     'percentCoverage': 96.0,
#     'datetimeFrom': {'utc': '2026-01-08T19:30:00Z',
#      'local': '2026-01-09T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-09T18:30:00Z',
#      'local': '2026-01-10T00:00:00+05:30'}}},
#   {'value': 171.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-09T18:30:00Z',
#      'local': '2026-01-10T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-10T18:30:00Z',
#      'local': '2026-01-11T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 71.0,
#     'q02': 74.22,
#     'q25': 115.0,
#     'median': 195.0,
#     'q75': 207.75,
#     'q98': 244.79999999999998,
#     'max': 254.0,
#     'avg': 171.08333333333334,
#     'sd': 55.80939352651219},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-09T19:30:00Z',
#      'local': '2026-01-10T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-10T18:30:00Z',
#      'local': '2026-01-11T00:00:00+05:30'}}},
#   {'value': 158.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-10T18:30:00Z',
#      'local': '2026-01-11T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-11T18:30:00Z',
#      'local': '2026-01-12T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 71.0,
#     'q02': 74.22,
#     'q25': 138.75,
#     'median': 167.0,
#     'q75': 184.0,
#     'q98': 225.85999999999999,
#     'max': 230.0,
#     'avg': 157.54166666666666,
#     'sd': 45.255774713593574},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-10T19:30:00Z',
#      'local': '2026-01-11T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-11T18:30:00Z',
#      'local': '2026-01-12T00:00:00+05:30'}}},
#   {'value': 167.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-11T18:30:00Z',
#      'local': '2026-01-12T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-12T18:30:00Z',
#      'local': '2026-01-13T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 51.0,
#     'q02': 51.92,
#     'q25': 112.5,
#     'median': 182.5,
#     'q75': 190.0,
#     'q98': 307.53999999999996,
#     'max': 331.0,
#     'avg': 166.54166666666666,
#     'sd': 69.64321837489022},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-11T19:30:00Z',
#      'local': '2026-01-12T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-12T18:30:00Z',
#      'local': '2026-01-13T00:00:00+05:30'}}},
#   {'value': 260.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-12T18:30:00Z',
#      'local': '2026-01-13T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-13T18:30:00Z',
#      'local': '2026-01-14T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 89.0,
#     'q02': 93.14,
#     'q25': 122.75,
#     'median': 316.5,
#     'q75': 350.25,
#     'q98': 398.79999999999995,
#     'max': 408.0,
#     'avg': 260.4166666666667,
#     'sd': 107.7332363593066},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-12T19:30:00Z',
#      'local': '2026-01-13T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-13T18:30:00Z',
#      'local': '2026-01-14T00:00:00+05:30'}}},
#   {'value': 237.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-13T18:30:00Z',
#      'local': '2026-01-14T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-14T18:30:00Z',
#      'local': '2026-01-15T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 112.0,
#     'q02': 117.52,
#     'q25': 158.75,
#     'median': 260.0,
#     'q75': 280.25,
#     'q98': 354.64,
#     'max': 362.0,
#     'avg': 237.125,
#     'sd': 71.85753568542835},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-13T19:30:00Z',
#      'local': '2026-01-14T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-14T18:30:00Z',
#      'local': '2026-01-15T00:00:00+05:30'}}},
#   {'value': 217.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-14T18:30:00Z',
#      'local': '2026-01-15T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-15T18:30:00Z',
#      'local': '2026-01-16T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 125.0,
#     'q02': 136.5,
#     'q25': 189.25,
#     'median': 205.0,
#     'q75': 258.5,
#     'q98': 284.02,
#     'max': 290.0,
#     'avg': 217.20833333333334,
#     'sd': 45.41593205096611},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-14T19:30:00Z',
#      'local': '2026-01-15T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-15T18:30:00Z',
#      'local': '2026-01-16T00:00:00+05:30'}}},
#   {'value': 220.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-15T18:30:00Z',
#      'local': '2026-01-16T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-16T18:30:00Z',
#      'local': '2026-01-17T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 89.0,
#     'q02': 96.04,
#     'q25': 179.5,
#     'median': 251.0,
#     'q75': 266.0,
#     'q98': 316.55999999999995,
#     'max': 339.0,
#     'avg': 220.30434782608697,
#     'sd': 67.38318834209498},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 23,
#     'observedInterval': '23:00:00',
#     'percentComplete': 96.0,
#     'percentCoverage': 96.0,
#     'datetimeFrom': {'utc': '2026-01-15T19:30:00Z',
#      'local': '2026-01-16T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-16T18:30:00Z',
#      'local': '2026-01-17T00:00:00+05:30'}}},
#   {'value': 368.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-16T18:30:00Z',
#      'local': '2026-01-17T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-17T18:30:00Z',
#      'local': '2026-01-18T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 245.0,
#     'q02': 247.3,
#     'q25': 311.25,
#     'median': 378.0,
#     'q75': 402.25,
#     'q98': 500.73999999999995,
#     'max': 515.0,
#     'avg': 367.625,
#     'sd': 64.0170431852473},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 24,
#     'observedInterval': '24:00:00',
#     'percentComplete': 100.0,
#     'percentCoverage': 100.0,
#     'datetimeFrom': {'utc': '2026-01-16T19:30:00Z',
#      'local': '2026-01-17T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-17T18:30:00Z',
#      'local': '2026-01-18T00:00:00+05:30'}}},
#   {'value': 297.0,
#    'flagInfo': {'hasFlags': False},
#    'parameter': {'id': 2,
#     'name': 'pm25',
#     'units': 'µg/m³',
#     'displayName': None},
#    'period': {'label': '1day',
#     'interval': '24:00:00',
#     'datetimeFrom': {'utc': '2026-01-17T18:30:00Z',
#      'local': '2026-01-18T00:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-18T18:30:00Z',
#      'local': '2026-01-19T00:00:00+05:30'}},
#    'coordinates': None,
#    'summary': {'min': 142.0,
#     'q02': 148.6,
#     'q25': 202.5,
#     'median': 312.0,
#     'q75': 360.0,
#     'q98': 463.48,
#     'max': 467.0,
#     'avg': 296.5217391304348,
#     'sd': 101.58050781079785},
#    'coverage': {'expectedCount': 24,
#     'expectedInterval': '24:00:00',
#     'observedCount': 23,
#     'observedInterval': '23:00:00',
#     'percentComplete': 96.0,
#     'percentCoverage': 96.0,
#     'datetimeFrom': {'utc': '2026-01-17T19:30:00Z',
#      'local': '2026-01-18T01:00:00+05:30'},
#     'datetimeTo': {'utc': '2026-01-18T18:30:00Z',
#      'local': '2026-01-19T00:00:00+05:30'}}}]}
